# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
sales_count = pd.read_csv('../data/Metro_sales_count_now_uc_sfrcondo_month.csv')

# %%
pd.set_option('display.max_columns',200)

# %%
sns.set_theme(style="darkgrid")
sns.color_palette("Reds")
# Out:
# [(0.9950634371395617, 0.8596539792387543, 0.7986620530565167),
#  (0.9882352941176471, 0.6866743560169165, 0.5778854286812765),
#  (0.9865897731641676, 0.5067281814686659, 0.38123798539023457),
#  (0.9570011534025374, 0.3087120338331411, 0.22191464821222606),
#  (0.8370472895040368, 0.13394848135332565, 0.13079584775086506),
#  (0.6663437139561708, 0.06339100346020761, 0.08641291810841982)]

# %%
condo_monthly = pd.read_csv('../data/Metro_zori_uc_sfrcondomfr_sm_month.csv')

# %%
condo_monthly
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName   2015-01-31  \
# 0      102001         0    United States    country       NaN  1253.449061
# 1      394913         1     New York, NY        msa        NY  2419.800397
# 2      753899         2  Los Angeles, CA        msa        CA  1848.680007
# 3      394463         3      Chicago, IL        msa        IL  1460.223748
# 4      394514         4       Dallas, TX        msa        TX  1138.255989
# ..        ...       ...              ...        ...       ...          ...
# 639    395130       890     Sterling, CO        msa        CO          NaN
# 640    394718       892    Jamestown, ND        msa        ND          NaN
# 641    394996       915     Portales, NM        msa        NM          NaN
# 642    394805       916   Los Alamos, NM        msa        NM          NaN
# 643    395186       932   Vermillion, SD        msa        SD          NaN
#
# ...

# %%
condo_monthly = condo_monthly.drop(columns = ['RegionID','RegionType'])

# %%
condo_monthly['RegionName'] = condo_monthly['RegionName'].str[:-4]

# %%
condo_monthly = condo_monthly[['RegionName','StateName','SizeRank','2020-01-31',	'2020-02-29',	'2020-03-31',	'2020-04-30',	'2020-05-31',	'2020-06-30',	'2020-07-31',	'2020-08-31',	'2020-09-30',	'2020-10-31',	'2020-11-30',	'2020-12-31',	'2021-01-31',	'2021-02-28',	'2021-03-31',	'2021-04-30',	'2021-05-31',	'2021-06-30',	'2021-07-31',	'2021-08-31',	'2021-09-30',	'2021-10-31',	'2021-11-30',	'2021-12-31',	'2022-01-31',	'2022-02-28',	'2022-03-31',	'2022-04-30',	'2022-05-31',	'2022-06-30',	'2022-07-31',	'2022-08-31',	'2022-09-30',	'2022-10-31',	'2022-11-30',	'2022-12-31',	'2023-01-31',	'2023-02-28',	'2023-03-31',	'2023-04-30',	'2023-05-31',	'2023-06-30',	'2023-07-31',	'2023-08-31',	'2023-09-30',	'2023-10-31',	'2023-11-30',	'2023-12-31',	'2024-01-31',	'2024-02-29',	'2024-03-31',	'2024-04-30',	'2024-05-31',	'2024-06-30']]

# %%
condo_monthly.to_csv('Monthly_rentprices.csv',index=False)
condo_monthly
# Out:
#       RegionName StateName  SizeRank   2020-01-31   2020-02-29   2020-03-31  \
# 0      United St       NaN         0  1537.677057  1546.346694  1554.832921
# 1       New York        NY         1  2739.368910  2753.611156  2763.993538
# 2    Los Angeles        CA         2  2383.984327  2388.659154  2388.698736
# 3        Chicago        IL         3  1662.224829  1674.192886  1689.710400
# 4         Dallas        TX         4  1405.337533  1412.148007  1420.284489
# ..           ...       ...       ...          ...          ...          ...
# 639     Sterling        CO       890          NaN          NaN          NaN
# 640    Jamestown        ND       892          NaN          NaN          NaN
# 641     Portales        NM       915          NaN          NaN          NaN
# 642   Los Alamos        NM       916          NaN          NaN          NaN
# 643   Vermillion        SD       932          NaN          NaN          NaN
#
# ...

# %%
condo_demand_index = pd.read_csv('../data/Metro_zordi_uc_condo_month.csv')
condo_demand_index
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName  2020-06-30  \
# 0      102001         0    United States    country       NaN        57.0
# 1      394913         1     New York, NY        msa        NY        59.0
# 2      753899         2  Los Angeles, CA        msa        CA        99.0
# 3      394463         3      Chicago, IL        msa        IL        71.0
# 4      394514         4       Dallas, TX        msa        TX        63.0
# ..        ...       ...              ...        ...       ...         ...
# 546    845169       874     Rockport, TX        msa        TX         NaN
# 547    394868       878     Mitchell, SD        msa        SD         NaN
# 548    394805       916   Los Alamos, NM        msa        NM         NaN
# 549    395112       922  Spirit Lake, IA        msa        IA         0.0
# 550    395186       932   Vermillion, SD        msa        SD         NaN
#
#      2020-07-31  2020-08-31  2020-09-30  2020-10-31  2020-11-30  2020-12-31  \
# ...

# %%
heat_index = pd.read_csv('../data/Metro_market_temp_index_uc_sfrcondo_month.csv')

# %%
heat_index
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName  2018-01-31  \
# 0      102001         0    United States    country       NaN        49.0
# 1      394913         1     New York, NY        msa        NY        50.0
# 2      753899         2  Los Angeles, CA        msa        CA        68.0
# 3      394463         3      Chicago, IL        msa        IL        48.0
# 4      394514         4       Dallas, TX        msa        TX        56.0
# ..        ...       ...              ...        ...       ...         ...
# 923    753929       935       Zapata, TX        msa        TX         NaN
# 924    394743       936    Ketchikan, AK        msa        AK        44.0
# 925    753874       937        Craig, CO        msa        CO        20.0
# 926    395188       938       Vernon, TX        msa        TX        53.0
# 927    394767       939       Lamesa, TX        msa        TX        46.0
#
#      2018-02-28  2018-03-31  2018-04-30  2018-05-31  2018-06-30  2018-07-31  \
# ...

# %%
wiki_tourist = pd.read_csv('../data/wiki_tourist_data.csv')
wiki_tourist_top = wiki_tourist[['State','Visitors (millions)']]
wiki_tourist_top
# Out:
#                State  Visitors (millions)
# 0         California                13.00
# 1           New York                42.00
# 2            Florida                13.89
# 3            Florida                11.48
# 4         California                18.76
# 5            Florida                12.44
# 6      Massachusetts                18.00
# 7         California                10.00
# 8         California                24.00
# 9           Arizona                  5.00
# 10    North Carolina                12.10
# 11         Tennessee                12.10
# 12            Nevada                42.00
# 13          Illinois                20.00
# 14          Michigan                 9.00
# 15           Florida                20.40
# 16         Minnesota                40.00
# 17          Illinois                25.00
# 18  Washington, D.C.                32.00
# 19          Illinois                 9.00
# 20        California                10.00
# ...

# %%
wiki_tourist_top = wiki_tourist_top.sort_values(by='Visitors (millions)',ascending = False)
wiki_tourist_top = wiki_tourist_top.groupby('State')['Visitors (millions)'].sum().reset_index().sort_values(by='Visitors (millions)',ascending=True).reset_index(drop=True)

# %%
plt.barh(y=wiki_tourist_top['State'], width=wiki_tourist_top['Visitors (millions)'], color = 'red')
plt.title('State Attraction populations 2021')
plt.xlabel('Population in Millions');

# %%
beaches_us = pd.read_csv('../data/list_beaches.csv')
beaches_us
# Out:
# C:\Users\Jasmine\AppData\Local\Temp\ipykernel_16620\3536311256.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   beaches_us = pd.read_csv('../data/list_beaches.csv')
#             New Jersey       Allenhurst
# 0           New Jersey      Asbury Park
# 1           New Jersey    Atlantic City
# 2           New Jersey           Avalon
# 3           New Jersey  Avon-by-the-Sea
# 4           New Jersey   Barnegat Light
# ...                ...              ...
# 1032220     New Mexico              NaN
# 1032221   North Dakota              NaN
# 1032222           Utah              NaN
# 1032223  West Virginia              NaN
# 1032224        Wyoming              NaN
#
# [1032225 rows x 2 columns]

# %%
top_10_bnb = pd.read_csv('../data/textextract.csv')
top_10_bnb
# Out:
#               City     County State  Occupancy Rate Percentage  \
# 0      New Orleans  Jefferson    LA                      52.62
# 1        Nashville   Davidson    TN                      54.99
# 2     Philadelphia   Delaware    PA                      49.80
# 3      San Antonio      Bexar    TX                      52.53
# 4          Atlanta     DeKalb    GA                      46.33
# 5      Miami-Miami       Dade    FL                      59.02
# 6           Dallas     Dallas    TX                      54.56
# 7           Denver      Adams    CO                      60.71
# 8  Fort Lauderdale    Broward    FL                      57.24
# 9           Boston  Middlesex    MA                      60.98
#
#    Number Of Airbnb Listings Gross Monthly Rental Income  Percentage Profit
# 0                       2880                     $3,399                5.92
# 1                       2838                     $3,714                5.64
# ...

# %%
us_bnb_data = pd.read_csv('../data/florida_occ.csv')
us_bnb_data
# Out:
#                  City  State Occupancy Rate       Zip codes  \
# 0         1. Kissimmee    FL            84%   34741 - 34759
# 1          2. Sarasota    FL            83%   34231 - 34249
# 2   3. Fort Lauderdale    FL            77%   33301 - 33394
# 3      4. Jacksonville    FL            73%   32202 - 32277
# 4             5. Tampa    FL            71%   33602 - 33664
# 5             6. Miami    FL            69%   33101 - 33206
# 6          7. Key West    FL            69%   33040 - 33045
# 7            8. Naples    FL            67%   34102 - 34120
# 8      9. Four Corners    FL            67%   33896 - 34787
# 9          10. Orlando    FL            54%   32801 - 32899
# 10    1. Santa Barbara    CA            84%   93101 - 93190
# 11         2. Yosemite    CA            84%           95389
# 12    3. San Francisco    CA            80%   33301 - 33394
# 13       4. Long Beach    CA            79%   90745 - 90899
# 14      5. Los Angeles    CA            76%   94101 - 94188
# ...

# %%
us_median_homeprice_2023 = pd.read_csv('../data/us_median_homeprice.csv')
top_15_price = us_median_homeprice_2023.head(15)
top_15_price = us_median_homeprice_2023[['Price','State']].sort_values(by = 'Price',ascending = False).reset_index().tail(15)
top_15_price
# Out:
#     index     Price          State
# 36     48  284000.0  West Virginia
# 37     27  280400.0       Nebraska
# 38     38  268100.0   Pennsylvania
# 39      0  267100.0        Alabama
# 40     13  266800.0       Illinois
# 41     16  263700.0         Kansas
# 42     17  246700.0       Kentucky
# 43      3  246000.0       Arkansas
# 44     25  243500.0       Missouri
# 45     18  243300.0      Louisiana
# 46     14  242500.0        Indiana
# 47     22  238800.0       Michigan
# 48     36  233900.0       Oklahoma
# 49     24  232800.0    Mississippi
# 50     35  228000.0           Ohio

# %%
plt.barh(y=top_15_price['State'], width=top_15_price['Price'], color = 'red')
plt.title('Lowest Home Price States')
plt.xlabel('Price')
# Out:
# Text(0.5, 0, 'Price')

# %%
florida_property_assess = pd.read_csv('../data/copy of assessed_value_fl.csv')
florida_property_assess.drop(columns=['Status'])
florida_property_assess
# Out:
#                          County   Status         2023 Value  \
# 0                       Alachua   R-NVAB     28,987,501,216
# 1                         Baker  R-Final      1,878,983,335
# 2                           Bay   R-NVAB     29,718,919,580
# 3                      Bradford  R-Final      1,455,056,252
# 4                       Brevard   R-NVAB     74,270,732,890
# ..                          ...      ...                ...
# 66                   Washington  R-Final      1,434,388,045
# 67                          NaN      NaN                NaN
# 68                    Statewide      NaN  3,301,353,471,877
# 69                          NaN      NaN                NaN
# 70  Data Extract: November 2023      NaN                NaN
#
#    Percent increase 2022-2023         2022 Value Percent increase 2021-2022  \
# 0                       8.71%     26,665,360,547                      7.85%
# 1                       8.95%      1,724,620,159                     11.98%
# ...

# %%
us_prop_tax_2022 = pd.read_csv('../data/us_property_taxes.csv')
us_prop_tax_2022['Effective Tax Rate'] = us_prop_tax_2022['Effective Tax Rate'].str[:-1]
us_prop_tax_2022['Effective Tax Rate'] = us_prop_tax_2022['Effective Tax Rate'].astype(float)
us_prop_tax_2022
# Out:
#     Rank                 State  Effective Tax Rate  \
# 0      1                Hawaii                0.32
# 1      2               Alabama                0.40
# 2      3              Colorado                0.55
# 3      4               Wyoming                0.56
# 4      5             Louisiana                0.56
# 5      6        South Carolina                0.57
# 6      7         West Virginia                0.57
# 7      8                  Utah                0.57
# 8      9                Nevada                0.59
# 9     10              Delaware                0.61
# 10    11  District of Columbia                0.62
# 11    12               Arizona                0.63
# 12    13              Arkansas                0.64
# 13    14                 Idaho                0.67
# 14    15             Tennessee                0.67
# 15    16           Mississippi                0.67
# 16    17            New Mexico                0.67
# ...

# %%
us_prop_tax_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Rank                             51 non-null     int64
#  1   State                            51 non-null     object
#  2   Effective Tax Rate               51 non-null     float64
#  3   Median Home Value or List Price  51 non-null     float64
#  4   Average Annual Property Tax      51 non-null     float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 2.1+ KB

# %%
us_prop_tax_2022_1 = us_prop_tax_2022[['Average Annual Property Tax','State']].sort_values(by = 'Average Annual Property Tax', ascending = False).tail(15).reset_index(drop=True)
us_prop_tax_2022_1
# Out:
#     Average Annual Property Tax                 State
# 0                       2067.97              Delaware
# 1                       1821.13              Oklahoma
# 2                       1815.55  District of Columbia
# 3                       1786.74                Oregon
# 4                       1710.91              Kentucky
# 5                       1637.70              Missouri
# 6                       1635.57             Tennessee
# 7                       1634.00               Montana
# 8                       1570.69                  Utah
# 9                       1404.42               Wyoming
# 10                      1369.60                Nevada
# 11                      1154.52              Arkansas
# 12                      1095.89             Louisiana
# 13                       937.29                Hawaii
# 14                       803.59               Alabama

# %%
vaca_vs_rent_2022 = pd.read_csv('../data/us_rent_vs_vaca.csv')
top_15_vaca_vs_rent_2022 = vaca_vs_rent_2022[['Vacation Rental NOI','State']]
top_15_vaca_vs_rent_2022 = top_15_vaca_vs_rent_2022.sort_values(by='Vacation Rental NOI', ascending = False).head(22).reset_index()

# %%
# grouped barplot
plt.barh(y=us_prop_tax_2022_1['State'], width=us_prop_tax_2022_1['Average Annual Property Tax'], color = 'red')
plt.title('Lowest Property Tax States')
plt.xlabel('Tax per Year in dollars')
# Out:
# Text(0.5, 0, 'Tax per Year in dollars')

# %%
vaca_vs_rent_2022
# Out:
#             City State  Beds  Median Rent  Monthly NOI  Avg Daily Rate  \
# 0    Albuquerque    NM     1        900.0        450.0           80.71
# 1    Albuquerque    NM     2       1150.0        575.0          123.05
# 2    Albuquerque    NM     3       1850.0        925.0          175.10
# 3    Albuquerque    NM     4       2200.0       1100.0          257.49
# 4      Arlington    TX     1       1000.0        500.0           83.25
# ..           ...   ...   ...          ...          ...             ...
# 195   Washington    DC     4       4500.0       2250.0          407.29
# 196      Wichita    KS     1        625.0        312.5           64.28
# 197      Wichita    KS     2        775.0        387.5          100.18
# 198      Wichita    KS     3       1070.0        535.0          127.06
# 199      Wichita    KS     4       1612.0        806.0          201.60
#
#      Avg Length of Stay  Avg Bookings  Vacation Rental NOI           Verdict  \
# ...

# %%
plt.barh(y=top_15_vaca_vs_rent_2022['State'], width=top_15_vaca_vs_rent_2022['Vacation Rental NOI'], color = 'red')
plt.title("Top NOI STR Revenue States");
plt.xlabel('NOI')
# Out:
# Text(0.5, 0, 'NOI')

# %%
vaca_vs_rent_2022['Monthly NOI'].sum()
# Out:
# 224516.25

# %%
vaca_vs_rent_2022['Vacation Rental NOI'].sum()
# Out:
# 244014.05000000002

# %%
vaca_vs_rent_2022
# Out:
#             City State  Beds  Median Rent  Monthly NOI  Avg Daily Rate  \
# 0    Albuquerque    NM     1        900.0        450.0           80.71
# 1    Albuquerque    NM     2       1150.0        575.0          123.05
# 2    Albuquerque    NM     3       1850.0        925.0          175.10
# 3    Albuquerque    NM     4       2200.0       1100.0          257.49
# 4      Arlington    TX     1       1000.0        500.0           83.25
# ..           ...   ...   ...          ...          ...             ...
# 195   Washington    DC     4       4500.0       2250.0          407.29
# 196      Wichita    KS     1        625.0        312.5           64.28
# 197      Wichita    KS     2        775.0        387.5          100.18
# 198      Wichita    KS     3       1070.0        535.0          127.06
# 199      Wichita    KS     4       1612.0        806.0          201.60
#
#      Avg Length of Stay  Avg Bookings  Vacation Rental NOI           Verdict  \
# ...

# %%
top_15_vaca_vs_rent_2022
# Out:
#     index  Vacation Rental NOI State
# 0      27              6142.12    MA
# 1     167              4766.84    CA
# 2      91              4003.80    CA
# 3      26              3724.03    MA
# 4     123              3660.01    TN
# 5     166              3431.69    CA
# 6      15              3343.07    TX
# 7     171              3160.86    CA
# 8      35              3109.85    IL
# 9     111              3021.78    FL
# 10     51              2694.46    CO
# 11     95              2572.05    CA
# 12    127              2552.33    NY
# 13    195              2542.79    DC
# 14     90              2521.38    CA
# 15    179              2466.41    WA
# 16    191              2373.81    VA
# 17    122              2349.10    TN
# 18    151              2341.33    OR
# 19    115              2272.49    WI
# 20    170              2266.12    CA
# 21     25              2160.79    MA

# %%
vaca_vs_rent_2022['Median Rent'].nlargest()
# Out:
# 127    7250.0
# 95     6495.0
# 171    5995.0
# 126    5695.0
# 111    5400.0
# Name: Median Rent, dtype: float64

# %%
vaca_vs_rent_2022['Median Rent'].nsmallest()
# Out:
# 196    625.0
# 56     700.0
# 184    769.0
# 197    775.0
# 96     825.0
# Name: Median Rent, dtype: float64

# %%
vaca_vs_rent_2022['State'].nunique()
# Out:
# 29

# %%
vaca_vs_rent_2022.plot(x= 'State')
# Out:
# <Axes: xlabel='State'>

# %%
occupancy = pd.read_csv('../data/us_occupancy_data.csv')
occupancy['Occupancy_2'] = occupancy['Occupancy Rate'].str[:-1]
occupancy
# Out:
#       State              City        Country Occupancy Rate Avg. Daily Rate  \
# 0    Arizona    Bullhead City  United States            50%           $167
# 1    Arizona            Mesa   United States            67%           $153
# 2    Arizona        Glendale   United States            61%           $196
# 3    Arizona         Phoenix   United States            66%           $159
# 4    Arizona  Fountain Hills   United States            61%           $240
# ..       ...              ...            ...            ...             ...
# 198   Texas    Wichita Falls   United States            61%           $102
# 199   Texas      San Antonio   United States            61%           $128
# 200   Texas       Richardson   United States            62%           $125
# 201   Texas            Plano   United States            65%           $154
# 202   Texas       Fort Worth   United States            62%           $117
#
#     Annual Revenue Total Listings Occupancy_2
# ...

# %%
occupancy['Occupancy_2'] = occupancy['Occupancy_2'].astype(int)

# %%
occupancy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 203 entries, 0 to 202
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   State            203 non-null    object
#  1   City             203 non-null    object
#  2   Country          203 non-null    object
#  3   Occupancy Rate   203 non-null    object
#  4   Avg. Daily Rate  203 non-null    object
#  5   Annual Revenue   203 non-null    object
#  6   Total Listings   203 non-null    object
#  7   Occupancy_2      203 non-null    int32
# dtypes: int32(1), object(7)
# memory usage: 12.0+ KB

# %%
occupancy['Occupancy Rate'].sort_values(ascending=False).head(15)
# Out:
# 30     93%
# 29     87%
# 121    80%
# 90     79%
# 28     79%
# 48     77%
# 152    75%
# 27     74%
# 75     74%
# 141    73%
# 140    73%
# 102    73%
# 31     72%
# 134    72%
# 21     72%
# Name: Occupancy Rate, dtype: object

# %%
list = [93,87,80,79,77,75,74,73,72]
top20 = occupancy.loc[occupancy['Occupancy_2'].isin(list)]
top20 = top20.sort_values(by='Occupancy_2', ascending = False).reset_index(drop=True)

# %%
top20
# Out:
#                    State             City        Country Occupancy Rate  \
# 0                  Hawaii          Kapaa   United States            93%
# 1                  Hawaii       Honolulu   United States            87%
# 2             New Jersey   West New York   United States            80%
# 3               Wisconsin        Madison   United States            79%
# 4                  Hawaii         Kailua   United States            79%
# 5               Minnesota      Rochester   United States            77%
# 6                  Maine       Ellsworth   United States            75%
# 7               Tennessee       Franklin   United States            74%
# 8                  Hawaii        Volcano   United States            74%
# 9              Washington      Shoreline   United States            73%
# 10                Florida   Longboat Key   United States            73%
# 11                Vermont     Burlington   United States            73%
# ...

# %%
plt.barh(y=top20['State '], width=top20['Occupancy_2'], color = 'red')
plt.title('Highest Occupancy by State')
plt.xlabel('Occupancy Rate(percentage)')
# Out:
# Text(0.5, 0, 'Occupancy Rate(percentage)')

# %%
occupancy['Annual Revenue_2'] = occupancy['Annual Revenue'].str[1:]
occupancy['Annual Revenue_2'] = occupancy['Annual Revenue_2'].str.replace(',' , '')
top15_revenue = occupancy[['Annual Revenue_2', 'State ']].sort_values(by = 'Annual Revenue_2', ascending = False)

# %%
top15_revenue['Annual Revenue_2'] =  top15_revenue['Annual Revenue_2'].astype(int)

# %%
top15_revenue = top15_revenue.reset_index(drop=True)
top15_revenue = top15_revenue.sort_values(by='Annual Revenue_2', ascending = False).reset_index(drop=True).head(20)
top15_revenue
# Out:
#     Annual Revenue_2          State
# 0             137340        Colorado
# 1              89084          Hawaii
# 2              82914            Utah
# 3              81065       Delaware
# 4              71761   Massachusetts
# 5              70220          Maine
# 6              70043   Massachusetts
# 7              69488     New Jersey
# 8              66641   Massachusetts
# 9              65660   Massachusetts
# 10             65452   Massachusetts
# 11             65371         Florida
# 12             61386        Michigan
# 13             60909  South Carolina
# 14             60360     New Jersey
# 15             59532        Maryland
# 16             58517          Nevada
# 17             58038      California
# 18             56460         Arizona
# 19             54322   Rhode Island

# %%
plt.barh(y=top15_revenue['State '], width=top15_revenue['Annual Revenue_2'], color = 'red')
plt.title('Top Revenues By State')
plt.xlabel('Revenue')
# Out:
# Text(0.5, 0, 'Revenue')

# %%
growth_pct = pd.read_csv('../data/Housing_increase_pct.csv')

# %%
top15_growth = growth_pct[['State/District','1-Year Growth']].head(15)
top15_growth['1-Year Growth'] = top15_growth['1-Year Growth'].str.replace('%','')
top15_growth = top15_growth.sort_values(by='1-Year Growth', ascending = True)

# %%
top15_growth['1-Year Growth']  =top15_growth['1-Year Growth'].astype(float)
top15_growth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15 entries, 14 to 0
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   State/District  15 non-null     object
#  1   1-Year Growth   15 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 360.0+ bytes

# %%
plt.figure(figsize = (10,4))
plt.barh(y=top15_growth['State/District'], width=top15_growth['1-Year Growth'], color = 'red')
plt.title('Top 1-Year Growth States')
plt.xlabel('Percent');

# %%
wiki_price_merge = pd.merge(top_15_price, wiki_tourist_top, 
                               left_on = 'State', right_on = 'State', 
                               how = 'outer')

# %%
tax_str_merge = pd.merge(top_15_vaca_vs_rent_2022,us_prop_tax_2022_1,
        left_on = 'State', right_on = 'State',
        how = 'outer')

# %%
rev_occ_merge = pd.merge(top20,top15_revenue,
        left_on = 'State ', right_on = 'State ',
        how = 'outer')

# %%
mega_merge = pd.merge(wiki_price_merge,tax_str_merge,
        left_on = 'State', right_on = 'State',
        how = 'outer')

# %%
ultra_merge = pd.merge(mega_merge,top15_growth,
        left_on = 'State', right_on = 'State/District',
        how = 'outer')

# %%
colossal_merge = pd.merge(ultra_merge,rev_occ_merge,
        left_on = 'State', right_on = 'State ',
        how = 'outer')

# %%
ultra_merge.columns
# Out:
# Index(['Price', 'State', 'Visitors (millions)', 'index', 'Vacation Rental NOI',
#        'Average Annual Property Tax', 'State/District', '1-Year Growth'],
#       dtype='object')

# %%
rev_occ_merge.columns
# Out:
# Index(['State ', 'City', 'Country', 'Occupancy Rate', 'Avg. Daily Rate',
#        'Annual Revenue', 'Total Listings', 'Occupancy_2', 'Annual Revenue_2'],
#       dtype='object')

# %%
colossal_merge
# Out:
#        Price        State  Visitors (millions)  index  Vacation Rental NOI  \
# 0   228000.0         Ohio                  NaN    NaN                  NaN
# 1   232800.0  Mississippi                  NaN    NaN                  NaN
# 2   233900.0     Oklahoma                  NaN    NaN                  NaN
# 3   238800.0     Michigan                  9.0    NaN                  NaN
# 4   242500.0      Indiana                  NaN    NaN                  NaN
# ..       ...          ...                  ...    ...                  ...
# 79       NaN          NaN                  NaN    NaN                  NaN
# 80       NaN          NaN                  NaN    NaN                  NaN
# 81       NaN          NaN                  NaN    NaN                  NaN
# 82       NaN          NaN                  NaN    NaN                  NaN
# 83       NaN          NaN                  NaN    NaN                  NaN
#
# ...

# %%
colossal_merge.columns
# Out:
# Index(['Price', 'State', 'Visitors (millions)', 'index', 'Vacation Rental NOI',
#        'Average Annual Property Tax', 'State/District', '1-Year Growth',
#        'State ', 'City', 'Country', 'Occupancy Rate', 'Avg. Daily Rate',
#        'Annual Revenue', 'Total Listings', 'Occupancy_2', 'Annual Revenue_2'],
#       dtype='object')

# %%
count_1 = colossal_merge['State'].value_counts()
count_1
# Out:
# State
# CA                      7
# Hawaii                  5
# Massachusetts           5
# MA                      3
# TN                      2
# Washington, D.C.        1
# New York                1
# TX                      1
# IL                      1
# FL                      1
# CO                      1
# NY                      1
# DC                      1
# WA                      1
# VA                      1
# OR                      1
# WI                      1
# Delaware                1
# District of Columbia    1
# Oregon                  1
# Montana                 1
# Utah                    1
# Wyoming                 1
# California              1
# Ohio                    1
# Mississippi             1
# Alabama                 1
# Oklahoma                1
# Michigan                1
# Indiana                 1
# Louisiana               1
# Missouri                1
# Arkansas                1
# Kentucky                1
# Kansas                  1
# ...

# %%
count_2 = colossal_merge['State '].value_counts()
count_2
# Out:
# State
# Hawaii                   5
# Massachusetts            5
# New Jersey               2
# Arizona                  1
# Maryland                 1
# Delaware                 1
# Colorado                 1
# South Carolina           1
# District of Columbia     1
# Vermont                  1
# Maine                    1
# Wisconsin                1
# Michigan                 1
# Washington               1
# Utah                     1
# Oregon                   1
# California               1
# Nevada                   1
# Minnesota                1
# Florida                  1
# Tennessee                1
# North Carolina           1
# Rhode Island             1
# Name: count, dtype: int64

# %%
colossal_merge
# Out:
#        Price        State  Visitors (millions)  index  Vacation Rental NOI  \
# 0   228000.0         Ohio                  NaN    NaN                  NaN
# 1   232800.0  Mississippi                  NaN    NaN                  NaN
# 2   233900.0     Oklahoma                  NaN    NaN                  NaN
# 3   238800.0     Michigan                  9.0    NaN                  NaN
# 4   242500.0      Indiana                  NaN    NaN                  NaN
# ..       ...          ...                  ...    ...                  ...
# 79       NaN          NaN                  NaN    NaN                  NaN
# 80       NaN          NaN                  NaN    NaN                  NaN
# 81       NaN          NaN                  NaN    NaN                  NaN
# 82       NaN          NaN                  NaN    NaN                  NaN
# 83       NaN          NaN                  NaN    NaN                  NaN
#
# ...

# %%
top_states_total = pd.read_csv('../data/top_states_total.csv')

# %%
top_states_total
# Out:
#                 State  Points
# 0   Hawaii                  8
# 1  California              14
# 2  Massachusetts            9
# 3  Florida                  6
# 4  Nevada                   4
# 5  Tennessee                6
# 6  Washington               3
# 7  Michigan                 3
# 8   Illinois                3

# %%
plt.figure(figsize = (15,12))
top_states_total.plot(kind = 'bar', x = 'State', color = 'red')
plt.xticks(rotation=0);

# %%
count_1 = wiki_tourist_top['State']

# %%
count_2 = top_15_price['State']

# %%
count_3 = us_prop_tax_2022_1['State']

# %%
count_4 = top_15_vaca_vs_rent_2022['State']

# %%
count_5 = top20['State ']

# %%
count_6 = top15_revenue['State ']

# %%
count_7 = top15_growth['State/District']

# %%
concat = pd.concat([count_1,count_2,count_3,count_4,count_5,count_6,count_7]).reset_index(drop=True).to_frame()

# %%
concat
# Out:
#                   0
# 0          Arizona
# 1          Michigan
# 2        Washington
# 3    North Carolina
# 4         Tennessee
# ..              ...
# 114           Idaho
# 115       Tennessee
# 116            Utah
# 117         Arizona
# 118         Florida
#
# [119 rows x 1 columns]

# %%
concat.value_counts().head(16)
# Out:
# Hawaii            8
# CA                7
# Massachusetts     6
# Tennessee         4
# Florida           4
# Nevada            4
# New Jersey        3
# Michigan          3
# South Carolina    3
# MA                3
# Utah              3
# North Carolina    3
# Washington        3
# Maine             2
# TN                2
# Oklahoma          2
# Name: count, dtype: int64

# %%
total_states = pd.read_csv('../data/top_states_total.csv')
total_states['State'] = total_states['State'].str.replace('Hawaii 8','Hawaii')
total_states = total_states.sort_values(by='Points',ascending = False)

# %%
plt.figure(figsize = (6,4))
ax=sns.barplot(data=total_states,x='State',y='Points', color ='red' )
plt.title("Count of Occurences in all KPI's")
plt.ylabel("Count")
plt.xticks(rotation=65);
